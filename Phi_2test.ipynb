# %% [markdown]
# <a href="https://colab.research.google.com/github/thompson129/Phi-2test/blob/main/Phi_2test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install einops
# !pip install accelerate
# !pip install optimum
# !pip install auto-gptq
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-i29hx95p
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-i29hx95p
#   Resolved https://github.com/huggingface/transformers to commit 29e7a1e1834f331a4916853ecd58549ed78235d6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.37.0.dev0-py3-none-any.whl size=8281393 sha256=9c049ce37fcd7b40e3b7ddd684834dbbe523f59233718e9b81f8bd01205e2a3e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gcjfc59u/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_name_or_path="TheBloke/phi-2-GPTQ"
model=AutoModelForCausalLM.from_pretrained(model_name_or_path,device_map="auto",trust_remote_code=True,revision="main")
tokenizer=AutoTokenizer.from_pretrained(model_name_or_path, use_fast=True)
# Out:
# config.json:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# configuration_phi.py:   0%|          | 0.00/2.03k [00:00<?, ?B/s]
# modeling_phi.py:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.84G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/69.0 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
prompt='''def print_prime(n):
   """
   Print all primes between 1 and n
   """'''
system_message="You are a senior software developer. Think step by step."
prompt_template=f'''{system_message} Instruct: {prompt}
Ans:
'''
print("***Pipeline:")
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100,do_sample=True,temperature=0.7,top_p=0.95,top_k=40,repetition_penalty=1.1)
print(pipe(prompt_template)[0]['generated_text'])
# Out:
# ***Pipeline:
# You are a senior software developer. Think step by step. Instruct: def print_prime(n):
#    """
#    Print all primes between 1 and n
#    """
# Ans:
#
# def print_prime(n):
#     # initialize an empty list to store the prime numbers
#     primes = []
#
#     # loop through each number from 2 to n
#     for i in range(2, n+1):
#         # check if the number is divisible by any other number
#         is_prime = True
#         for j in range(2, int(i**0.5)+1):
#             if (i % j == 0):

# %%
prompt='''def find_fibonacci(n):
   """
   Return the first n Fibonacci numbers
   """'''
system_message="You are a python coding expert. Think step by step."
prompt_template=f'''{system_message} Instruct: {prompt}
Ans:
'''
print("***Pipeline:")
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100,do_sample=True,temperature=0.7,top_p=0.95,top_k=40,repetition_penalty=1.1)
print(pipe(prompt_template)[0]['generated_text'])
# Out:
# ***Pipeline:
# You are a python coding expert. Think step by step. Instruct: def find_fibonacci(n):
#    """
#    Return the first n Fibonacci numbers
#    """
# Ans:
# #!/usr/bin/env python3
#
# import cv2
# from PIL import Image
# import numpy as np
# import argparse
#
#
# def main():
#
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--input', required=True, help='Input image')
#     parser.add_argument('--output', required=True, help='Output image')
#     parser.add_argument('--mode', choices

# %%
prompt='''def merge_sorted_arrays(arr1,arr2):
   """
   Merge two sorted arrays into one sorted array
   """'''
system_message="You are a senior software developer. Think step by step to write optimized code."
prompt_template=f'''{system_message} Instruct: {prompt}
Ans:
'''
print("***Pipeline:")
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=300,do_sample=True,temperature=0.7,top_p=0.95,top_k=40,repetition_penalty=1.1)
print(pipe(prompt_template)[0]['generated_text'])
# Out:
# ***Pipeline:
# You are a senior software developer. Think step by step to write optimized code. Instruct: def merge_sorted_arrays(arr1,arr2):
#    """
#    Merge two sorted arrays into one sorted array
#    """
# Ans:
#
# def merge_sorted_arrays(arr1,arr2):
#
#     # Initialize an empty list that will hold the merged array
#     merged_list = []
#
#     i, j = 0,0 # Initialize indexes for both lists
#
#     while i < len(arr1) and j < len(arr2):
#         if arr1[i] <= arr2[j]: # If current element of first list is smaller than or equal to current element of second list
#             merged_list.append(arr1[i]) # Append it to the merged list
#             i+=1
#         else: # If current element of first list is greater than current element of second list
#             merged_list.append(arr2[j]) # Append it to the merged list
#             j+=1
#
#     # append remaining elements from the original lists
#     while i<len(arr1):
#         merged_list.append(arr1[i])
#         i+=1
# ...

# %%
prompt='''def find_top_n_customers(purchase_data,n):
   """
   Identify the top n customers with the highest total purchase amount from purchase data.
   Args:
    purchase_data (list of dicts): Each dict contains 'customer_id' and 'purchase_amount'.
    n (int): Number of top customers to identify.

    Returns:
    list: A list of customer IDs for the top n customers based on total purchase amount.

    Example:
    purchase_data = [
        {'customer_id': 'C001', 'purchase_amount': 250},
        {'customer_id': 'C002', 'purchase_amount': 300},
        {'customer_id': 'C001', 'purchase_amount': 150},
        ... (more records) ...
    ]

    For n = 2, the function should return the customer IDs of the two customers with the highest total purchase amount.
   """'''
system_message="You are a senior data scientist. Think step by step."
prompt_template=f'''{system_message} Instruct: {prompt}
Ans:
'''
print("***Pipeline:")
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=300,do_sample=True,temperature=0.7,top_p=0.95,top_k=40,repetition_penalty=1.1)
print(pipe(prompt_template)[0]['generated_text'])
# Out:
# ***Pipeline:
# You are a senior data scientist. Think step by step. Instruct: def find_top_n_customers(purchase_data,n):
#    """
#    Identify the top n customers with the highest total purchase amount from purchase data.
#    Args:
#     purchase_data (list of dicts): Each dict contains 'customer_id' and 'purchase_amount'.
#     n (int): Number of top customers to identify.
#
#     Returns:
#     list: A list of customer IDs for the top n customers based on total purchase amount.
#
#     Example:
#     purchase_data = [
#         {'customer_id': 'C001', 'purchase_amount': 250},
#         {'customer_id': 'C002', 'purchase_amount': 300},
#         {'customer_id': 'C001', 'purchase_amount': 150},
#         ... (more records) ...
#     ]
#
#     For n = 2, the function should return the customer IDs of the two customers with the highest total purchase amount.
#    """
# Ans:
# ...
